# %% [markdown]
# ##### import the titanic dataset

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the fare of class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv(r"C:\Users\ADMIN\python files\assignments\Data_visualization\Data_visualization_day_2\titanic.csv")
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
x=data[data['class']=='First']['fare'].mean()
y=data[data['class']=='Second']['fare'].mean()
z=data[data['class']=='Third']['fare'].mean()
plt.bar(['Frist','Second','Thrid'],[x,y,z])
plt.ylabel('mean of fare')
# Out:
# Text(0, 0.5, 'mean of fare')

# %%
x=data[data['sex']=='male']['fare'].mean()
y=data[data['sex']=='female']['fare'].mean()
plt.bar(['male','female'],[x,y])
plt.ylabel('mean of fare')
# Out:
# Text(0, 0.5, 'mean of fare')

# %% [markdown]
# ###### 2. Write a Python program to display a horizontal bar chart of the fare of class.

# %%
plt.barh(['Frist','Second','Thrid'],[x,y,z])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ###### 3. Write a Python program to display a bar chart of the fare of class. Use different color for each bar.

# %%
x=data[data['class']=='First']['fare'].mean()
y=data[data['class']=='Second']['fare'].mean()
z=data[data['class']=='Third']['fare'].mean()
sb.barplot(['Frist','Second','Thrid'],[x,y,z])
plt.ylabel('mean of fare')
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'mean of fare')

# %% [markdown]
# ###### 4. Write a Python program to create a pie chart of the fare of class.

# %%
plt.pie([x,y,z],labels=['Frist','Second','Thrid'],autopct='%0.1f%%',radius=2)
plt.show()

# %% [markdown]
# ######5. Write a Python program to display a count plot of all categorical columns.

# %%
sb.countplot(data['sex'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['embarked'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['who'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['class'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['adult_male'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['deck'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['embark_town'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['alive'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(data['alone'])
plt.show()
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ###### 6. Write a Python program to display a factor plot of ( pclass vs embarked). hist (kind = 'count')

# %%
sb.histplot(data=data,x='pclass',bins=3,hue='embarked')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %% [markdown]
# ###### 7. Write a Python programming to display a factor plot of ( pclass vs sex). hist (kind = 'count')

# %%
sb.histplot(data=data,x='pclass',bins=3,hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Count'>

# %% [markdown]
# ###### 8. Write a Python programming to display a factor plot of ( embarked vs sex). hist (kind = 'count')

# %%
sb.histplot(data=data,x='embarked',bins=3,hue='sex')
# Out:
# <AxesSubplot:xlabel='embarked', ylabel='Count'>

# %% [markdown]
# ###### 9. Write a Python program to display distribution plot for all numberical columns.

# %%
m=sb.FacetGrid(data=data,hue='sex',height=5)
m.map(sb.distplot,'survived')
m.add_legend()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
m=sb.FacetGrid(data=data,hue='sex',height=5)
m.map(sb.distplot,'pclass')
m.add_legend()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
m=sb.FacetGrid(data=data,hue='sex',height=5)
m.map(sb.distplot,'age')
m.add_legend()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
m=sb.FacetGrid(data=data,hue='sex',height=5)
m.map(sb.distplot,'sibsp')
m.add_legend()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
m=sb.FacetGrid(data=data,hue='sex',height=5)
m.map(sb.distplot,'parch')
m.add_legend()
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### 10. Write a Python program to display boxplot of age, pclass and hue = gender.

# %%
sb.boxplot(data=data,y='age',x='pclass',hue='sex')
plt.show()

# %% [markdown]
# ##### Bonus Question

# %% [markdown]
# ##### 1. What are the plots we can create on numerical columns.

# %%
Histogram, Distplot, kdeplot,

# %% [markdown]
# ###### 2. What are the plots we can create on categorical columns.

# %%
#do anaylsis on one numerical and catogerical axis then we use swarn plot, strip plot,boxplot, violinplot,bargraph
