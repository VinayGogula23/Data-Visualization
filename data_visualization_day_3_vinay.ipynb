# %% [markdown]
# ##### import tips dataset.

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv(r"C:\Users\Gogula Vinay\Desktop\Innomatics labs\Data Science\lms assignment\10. Data Visualization\Data_visualization\Data_visualization_day_3\tips.csv")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data[data['smoker']=='Yes'].min()
# Out:
# total_bill      3.07
# tip              1.0
# sex           Female
# smoker           Yes
# day              Fri
# time          Dinner
# size               1
# dtype: object

# %%
x=data[data['sex']=='Male']['total_bill'].sum()
y=data[data['sex']=='Female']['total_bill'].sum()
plt.bar(['Male','Female'],[x,y])
plt.ylabel('total_bill')
plt.show()
# total_bill made by the gender male is more the gender female

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
sb.boxplot(data=data,y='total_bill',hue='smoker')
#the max total
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
sb.violinplot(data=data,y='total_bill',x='sex',hue='sex',size=10)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
sb.stripplot(data=data,y='total_bill',x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
sb.heatmap(data.corr().round(1),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
sb.scatterplot(data=data,y='total_bill',x='tip',hue='sex')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
sb.kdeplot(x=data['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sb.kdeplot(x=data['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sb.kdeplot(x=data['size'])
# Out:
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
x
# Out:
# 3256.8199999999997

# %%
x=data.pivot_table(columns='day',aggfunc=({'total_bill':np.mean}))
sb.barplot(['Fri','Sat','Sun','Thur'],[x['Fri'][0],x['Sat'][0],x['Sun'][0],x['Thur'][0]])
plt.ylabel('avg of total_bill')
# Out:
# C:\Users\Gogula Vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'avg of total_bill')

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %%
A histogram takes as input a numeric variable only. The variable is cut into several bins, and the number of observation per
bin is represented by the height of the bar. It is possible to represent the distribution of several variable on the same axis 
using this technique.

# %% [markdown]
# ##### 2. What is box plot ?

# %%
A boxplot gives a nice summary of one or several numeric variables. The line that divides the box into 2 parts represents the
median of the data. The end of the box shows the upper and lower quartiles. The extreme lines show the highest and lowest value
excluding outliers.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %%
Histplot, distplot, kdeplot, boxplot, pieplot, countplot

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %%
Scatterplot, regplot, jointplot, barplot, boxplot, voilenplot,lineplot

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %%
Heatmap, Correlation matrix.
